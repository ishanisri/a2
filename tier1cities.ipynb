# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('C:/Users/Harini/Desktop/file1.csv')
table=pd.pivot_table(data,index=['Outlet_Location_Type','Item_Identifier','Item_Type','Outlet_Type'],values=['Item_Type','Item_MRP','Item_Outlet_Sales'])
tier1=table.xs('Tier 1',level=0)
tier1
# Out:
#                                                       Item_MRP  \
# Item_Identifier Item_Type          Outlet_Type
# DRA24           Soft Drinks        Grocery Store      163.2868
#                                    Supermarket Type1  165.0868
# DRA59           Soft Drinks        Grocery Store      186.2924
#                                    Supermarket Type1  184.2924
# DRB01           Soft Drinks        Supermarket Type1  187.7530
# DRB13           Soft Drinks        Supermarket Type1  188.6530
# DRB24           Soft Drinks        Supermarket Type1  155.1656
# DRB48           Soft Drinks        Supermarket Type1   38.6322
# DRC01           Soft Drinks        Supermarket Type1   47.7692
# DRC12           Soft Drinks        Supermarket Type1  190.0688
# DRC25           Soft Drinks        Grocery Store       86.7882
#                                    Supermarket Type1   86.0882
# DRC27           Dairy              Supermarket Type1  246.9802
# ...

# %%
table1=pd.pivot_table(tier1,index=['Outlet_Type','Item_Type'],values=['Item_Outlet_Sales'],aggfunc=[np.sum,len])
table1
# Out:
#                                                       sum               len
#                                         Item_Outlet_Sales Item_Outlet_Sales
# Outlet_Type       Item_Type
# Grocery Store     Baking Goods                 14133.6024              43.0
#                   Breads                        4947.5598              16.0
#                   Breakfast                     3762.4358              10.0
#                   Canned                       16739.5436              38.0
#                   Dairy                        16144.3184              49.0
#                   Frozen Foods                 15252.8122              49.0
#                   Fruits and Vegetables        24054.0224              73.0
#                   Hard Drinks                   1768.3648               8.0
#                   Health and Hygiene           10945.0862              30.0
#                   Household                    18157.0318              52.0
# ...

# %%
groctier1=table1.xs('Grocery Store',level=0)
groctier1
# Out:
#                                     sum               len
#                       Item_Outlet_Sales Item_Outlet_Sales
# Item_Type
# Baking Goods                 14133.6024              43.0
# Breads                        4947.5598              16.0
# Breakfast                     3762.4358              10.0
# Canned                       16739.5436              38.0
# Dairy                        16144.3184              49.0
# Frozen Foods                 15252.8122              49.0
# Fruits and Vegetables        24054.0224              73.0
# Hard Drinks                   1768.3648               8.0
# Health and Hygiene           10945.0862              30.0
# Household                    18157.0318              52.0
# Meat                         11995.7186              32.0
# Others                        4522.1136              17.0
# Seafood                       1336.9264               6.0
# Snack Foods                  25653.2740              75.0
# ...

# %%
n1=groctier1['sum']



n2=n1.as_matrix(['Item_Outlet_Sales'])

c=[]
a=n2.tolist()
for i in range(len(n2)):
    c.append(a[i][0])


n4=data.Item_Type.unique().tolist()
n4.sort()


d=[]
for i in range(len(n2)):
    d.append(i)
    
    
plt.bar(d,c,width=0.3,color='r')
plt.xticks(d,n4,rotation='vertical')
plt.title('Graph of total sales of items bought in each category in tier 1 city grocery store')
plt.grid()
plt.xlabel('Item Type')
plt.ylabel('total sales')
plt.figure(figsize=(20,3))


plt.show()
n3=n1.sort_values('Item_Outlet_Sales')
n3
# Out:
#                        Item_Outlet_Sales
# Item_Type
# Starchy Foods                  1167.8132
# Seafood                        1336.9264
# Hard Drinks                    1768.3648
# Breakfast                      3762.4358
# Others                         4522.1136
# Breads                         4947.5598
# Soft Drinks                    9113.4704
# Health and Hygiene            10945.0862
# Meat                          11995.7186
# Baking Goods                  14133.6024
# Frozen Foods                  15252.8122
# Dairy                         16144.3184
# Canned                        16739.5436
# Household                     18157.0318
# Fruits and Vegetables         24054.0224
# Snack Foods                   25653.2740

# %%
p1=groctier1['len']
p2=p1.as_matrix(['Item_Outlet_Sales'])
c1=[]
a1=p2.tolist()
for i in range(len(n2)):
    c1.append(a1[i][0])


p4=data.Item_Type.unique().tolist()
p4.sort()


d1=[]
for i in range(len(p2)):
    d1.append(i)
plt.bar(d1,c1,width=0.3,color='r')
plt.xticks(d1,p4,rotation='vertical')


plt.title('Graph of no of items bought in each category in tier 1 city grocery store')
plt.xlabel('Item Type')
plt.ylabel('no of items')
plt.figure(figsize=(20,3))


plt.show()
p1.sort_values('Item_Outlet_Sales')
# Out:
#                        Item_Outlet_Sales
# Item_Type
# Starchy Foods                        4.0
# Seafood                              6.0
# Hard Drinks                          8.0
# Breakfast                           10.0
# Breads                              16.0
# Others                              17.0
# Soft Drinks                         26.0
# Health and Hygiene                  30.0
# Meat                                32.0
# Canned                              38.0
# Baking Goods                        43.0
# Dairy                               49.0
# Frozen Foods                        49.0
# Household                           52.0
# Fruits and Vegetables               73.0
# Snack Foods                         75.0

# %%
suptier1=table1.xs('Supermarket Type1',level=0)
suptier1
# Out:
#                                     sum               len
#                       Item_Outlet_Sales Item_Outlet_Sales
# Item_Type
# Baking Goods                224159.8795             100.0
# Breads                       90247.5255              36.0
# Breakfast                    35913.5849              16.0
# Canned                      234990.4481             105.0
# Dairy                       244295.3360             109.0
# Frozen Foods                321171.2672             141.0
# Fruits and Vegetables       434034.0213             183.0
# Hard Drinks                  75283.6705              35.0
# Health and Hygiene          174041.4516              77.0
# Household                   338190.4468             140.0
# Meat                        132900.0051              63.0
# Others                       61673.7198              28.0
# Seafood                      23854.6153               9.0
# Snack Foods                 443307.2837             185.0
# ...

# %%
n1=suptier1['sum']



n2=n1.as_matrix(['Item_Outlet_Sales'])

c=[]
a=n2.tolist()
for i in range(len(n2)):
    c.append(a[i][0])


n4=data.Item_Type.unique().tolist()
n4.sort()


d=[]
for i in range(len(n2)):
    d.append(i)
    
    
plt.bar(d,c,width=0.3,color='r')
plt.xticks(d,n4,rotation='vertical')
plt.title('Graph of total sales of items bought in each category in tier 1 city supermarket type1')
plt.grid()
plt.xlabel('Item Type')
plt.ylabel('total sales')
plt.figure(figsize=(20,3))


plt.show()
n3=n1.sort_values('Item_Outlet_Sales')
n3
# Out:
#                        Item_Outlet_Sales
# Item_Type
# Seafood                       23854.6153
# Breakfast                     35913.5849
# Others                        61673.7198
# Starchy Foods                 63201.3979
# Hard Drinks                   75283.6705
# Breads                        90247.5255
# Soft Drinks                  132696.2703
# Meat                         132900.0051
# Health and Hygiene           174041.4516
# Baking Goods                 224159.8795
# Canned                       234990.4481
# Dairy                        244295.3360
# Frozen Foods                 321171.2672
# Household                    338190.4468
# Fruits and Vegetables        434034.0213
# Snack Foods                  443307.2837

# %%
p1=suptier1['len']
p2=p1.as_matrix(['Item_Outlet_Sales'])
c1=[]
a1=p2.tolist()
for i in range(len(n2)):
    c1.append(a1[i][0])


p4=data.Item_Type.unique().tolist()
p4.sort()


d1=[]
for i in range(len(p2)):
    d1.append(i)
plt.bar(d1,c1,width=0.3,color='r')
plt.xticks(d1,p4,rotation='vertical')


plt.title('Graph of no of items bought in each category in tier 1 city supermarket type1')
plt.xlabel('Item Type')
plt.ylabel('no of items')
plt.figure(figsize=(20,3))


plt.show()
p1.sort_values('Item_Outlet_Sales')
# Out:
#                        Item_Outlet_Sales
# Item_Type
# Seafood                              9.0
# Breakfast                           16.0
# Starchy Foods                       26.0
# Others                              28.0
# Hard Drinks                         35.0
# Breads                              36.0
# Meat                                63.0
# Soft Drinks                         67.0
# Health and Hygiene                  77.0
# Baking Goods                       100.0
# Canned                             105.0
# Dairy                              109.0
# Household                          140.0
# Frozen Foods                       141.0
# Fruits and Vegetables              183.0
# Snack Foods                        185.0

# %%
mrptable=tier1['Item_MRP']
mrptable.max()
# Out:
# 266.88839999999999

# %%
mrpno=[0,0,0,0,0,0]
l1=tier1['Item_MRP'].tolist()
l1
for i in range(len(l1)):
    if l1[i]<=50 :
        mrpno[0]=mrpno[0]+1
    elif l1[i]<=100:
        mrpno[1]=mrpno[1]+1
    elif l1[i]<=150:
        mrpno[2]=mrpno[2]+1  
    elif l1[i]<=200:
        mrpno[3]=mrpno[3]+1  
    elif l1[i]<=250:
        mrpno[4]=mrpno[4]+1
    elif l1[i]<=300:
        mrpno[5]=mrpno[5]+1 
rects1=plt.bar([50,100,150,200,250,300],mrpno,width=-50.0,align='edge')  
plt.ylabel('No of items bought')
plt.xlabel('MRP range')
plt.title('plot of MRP range vs items bought in tier 1 cities')



plt.grid()    

plt.show() 
mrpno
# Out:
# [170, 366, 482, 520, 218, 92]
